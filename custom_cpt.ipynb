# %%
import pygmt
grid = pygmt.datasets.load_earth_relief(resolution="05m", region=[-86, -64 , 17, 24])

# %%
fig = pygmt.Figure()
pygmt.makecpt(cmap="jet", series="-8500/0/1000", continuous=True)
fig.grdimage(grid=grid, projection="M6i", frame=True)
fig.colorbar()
fig.show()

# %%
fig = pygmt.Figure()
pygmt.makecpt(cmap="jet", series="-9000/3000/1500")#, continuous=True)
fig.grdimage(grid=grid, projection="M6i", frame=True)
fig.colorbar()
fig.show()

# %%
fig = pygmt.Figure()
pygmt.makecpt(cmap="jet", series="-8500/2500")#, continuous=True)
fig.grdimage(grid=grid, projection="M6i", frame=True)
fig.colorbar()
fig.show()

# %%
fig = pygmt.Figure()
pygmt.makecpt(cmap="jet", series="-8500/2500", continuous=False)
fig.grdimage(grid=grid, projection="M6i", frame=True)
fig.colorbar(frame="p2000")
fig.show()

# %%
fig = pygmt.Figure()
pygmt.makecpt(cmap="jet", series="-9000/3000/1500")
fig.grdimage(grid=grid, projection="M6i", frame=True)
fig.colorbar(frame=["p3000", "x+lElevation", "y+lm"])
fig.show()
