# %%
import pygmt

# %%
fig = pygmt.Figure()
fig.coast(region="-90/20/-55/25+r", frame="afg", land="red", water="cyan", resolution="i", projection="Oa280/25.5/-60/12c")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region="-90/20/-55/25+r", frame="afg", land="red", projection="Ob-80/20/-70/15/12c")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region="125/-10/155/0+r", frame="afg", land="red", projection="OC140/-5/106/-60/12c")
fig.show()
