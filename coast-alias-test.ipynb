# %%
import pygmt

# %%
fig = pygmt.Figure()
fig.coast(
    region="-30/30/-40/40", #R
    projection="m0.1i", #J
    frame="afg", #B
    rivers="1/1p,black", #I
    borders="1/0.5p,-", #N
    shorelines="0.25p,white", #W
    land="moccasin", #G
    water="skyblue", #S
    resolution="i", #D
    area_thresh=1000, #A
    #L
    #U
    #V #verbose (may not need)
    #X
    #Y
    #p
    #t
)
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(
    #region="-30/30/-40/40", #R
    region=[-30,30,-40,40], #R
    projection="M25c", #J
    frame="afg", #B
    rivers="1/1p,black", #I
    borders="1/0.5p,-", #N
    shorelines="0.25p,white", #W
    land="moccasin", #G
    water="skyblue", #S
    resolution="i", #D
    area_thresh=1000, #A
    map_scale="jMM+c1+w1000k+f+l", #L
    timestamp=True, #U
    verbose="q", #V
    xshift = "a4c", #X
    yshift = "a10c", #Y
    perspective = "135/25",#p
    transparency = 13, #t
)
fig.show()
