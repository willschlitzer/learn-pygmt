# %%
import pygmt

# %%
my_bin = pygmt.binstats(data="@capitals.gmt", region="g", spacing=5, compute="z", S="1000k", a="2=population")

# %%
fig = pygmt.Figure()

# %%
fig.grdimage(grid=my_bin, frame="a")

# %%
fig.show()
