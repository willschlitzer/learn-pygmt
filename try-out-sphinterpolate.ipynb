# %%
import pygmt

# %%
grid = pygmt.sphinterpolate(table="@mars370d.txt", increment=0.5, region="g")

# %%
fig = pygmt.Figure()
fig.grdimage(grid=grid, projection="H0/4.5i", frame=True)
fig.show()

# %%
print(pygmt.grdinfo(grid=grid))
# Out:
# : Title:
# : Command:
# : Remark:
# : Gridline node registration used [Geographic grid]
# : Grid file format: nf = GMT netCDF format (32-bit float), CF-1.7
# : x_min: 0 x_max: 360 x_inc: 0.5 (30 min) name: x n_columns: 721
# : y_min: -90 y_max: 90 y_inc: 0.5 (30 min) name: y n_rows: 361
# : v_min: -6928.13232422 v_max: 14896.1425781 name: z
# : scale_factor: 1 add_offset: 0
# : format: classic
