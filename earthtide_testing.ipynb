# %%
import pygmt

# %%
#gmt earthtide -S
grid = pygmt.earthtide(sunmoon=True)
# Out:
# earthtide [WARNING]: time crossed leap seconds table boundaries. Boundary edge used instead.

# %%
#gmt earthtide -T2018-06-18T12:00:00 -Gsolid_tide_up.grd
grid = pygmt.earthtide(time="2018-06-18T12:00:00")
grid
# Out:
# <xarray.DataArray 'z' (lat: 361, lon: 721)>
# array([[-0.12985276, -0.12985276, -0.12985276, ..., -0.12985276,
#         -0.12985276, -0.12985276],
#        [-0.1286162 , -0.12860492, -0.12859371, ..., -0.12863906,
#         -0.12862758, -0.1286162 ],
#        [-0.1273604 , -0.1273375 , -0.12731476, ..., -0.12740676,
#         -0.12738349, -0.1273604 ],
#        ...,
#        [-0.13349742, -0.13351837, -0.13353913, ..., -0.13345495,
#         -0.13347629, -0.13349742],
#        [-0.13231565, -0.13232629, -0.13233684, ..., -0.13229409,
#         -0.1323049 , -0.13231565],
#        [-0.13111365, -0.13111365, -0.13111365, ..., -0.13111365,
#         -0.13111365, -0.13111365]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.5 -179.0 -178.5 ... 179.0 179.5 180.0
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
# Attributes:
#     long_name:     solid-earth-tide
#     units:         meter
# ...

# %%
grid = pygmt.earthtide(time="2018-06-18T/2018-06-19T/1m")
grid
# Out:
# <xarray.DataArray 'z' (lat: 361, lon: 721)>
# array([[-0.12576035, -0.12576035, -0.12576035, ..., -0.12576035,
#         -0.12576035, -0.12576035],
#        [-0.1272288 , -0.12724079, -0.12725265, ..., -0.1272045 ,
#         -0.12721671, -0.1272288 ],
#        [-0.12867337, -0.12869695, -0.12872028, ..., -0.12862556,
#         -0.12864958, -0.12867337],
#        ...,
#        [-0.12422624, -0.12420163, -0.12417724, ..., -0.12427612,
#         -0.12425108, -0.12422624],
#        [-0.12572439, -0.12571229, -0.1257003 , ..., -0.12574893,
#         -0.12573661, -0.12572439],
#        [-0.1271992 , -0.1271992 , -0.1271992 , ..., -0.1271992 ,
#         -0.1271992 , -0.1271992 ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.5 -179.0 -178.5 ... 179.0 179.5 180.0
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
# Attributes:
#     long_name:     solid-earth-tide
#     units:         meter
# ...

# %%
grid = pygmt.earthtide(time="2018-06-18T12:00:00",
                       region=[6, 9, 13, 17], spacing=[1, 2])
grid
# Out:
# <xarray.DataArray 'z' (lat: 3, lon: 4)>
# array([[0.04949933, 0.05444588, 0.05942686, 0.06443665],
#        [0.05169343, 0.05663284, 0.06160447, 0.06660277],
#        [0.05337802, 0.05829764, 0.06324723, 0.06822133]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 6.0 7.0 8.0 9.0
#   * lat      (lat) float64 13.0 15.0 17.0
# Attributes:
#     long_name:     solid-earth-tide
#     units:         meter
#     actual_range:  [0.04949933 0.06822133]

# %%
#grid = pygmt.earthtide(time="2018-06-18T12:00:00", region=[6, 9, 13, 17])
#grid

# %%
grid3 = pygmt.earthtide(time="2018-06-18T12:00:00", location=[-5, 25])
grid3
# Out:
# <xarray.DataArray 'z' (lat: 3, lon: 4)>
# array([[0.04949933, 0.05444588, 0.05942686, 0.06443665],
#        [0.05169343, 0.05663284, 0.06160447, 0.06660277],
#        [0.05337802, 0.05829764, 0.06324723, 0.06822133]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 6.0 7.0 8.0 9.0
#   * lat      (lat) float64 13.0 15.0 17.0
# Attributes:
#     long_name:     solid-earth-tide
#     units:         meter
#     actual_range:  [0.04949933 0.06822133]
