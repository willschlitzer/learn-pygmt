# %%
import pygmt
#grid = pygmt.datasets.load_earth_relief(resolution="05m", region=[-92.5, -82.5, -3, 7])

# %%
#fig = pygmt.Figure()
#fig.basemap(region=[-92.5, -82.5, -3, 7])
#fig.show()

# %%
fig = pygmt.Figure()
#fig.basemap(frame="f")
fig.coast(shorelines="1/0.5p", region="IS")
fig.basemap(rose="jBR+w5c")
#fig.basemap(compass="jBR+w5c+d-4.5")
#fig.basemap(map_scale="jBR+w5c")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=[127.5, 128.5, 26, 27], shorelines="1/0.5p" )
fig.basemap(rose="jBR+w5c")
#fig.savefig("rose.png")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=[127.5, 128.5, 26, 27], shorelines="1/0.5p" )
fig.basemap(compass="jBR+w5c+d11.5")
fig.savefig("compass.png")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=[127.5, 128.5, 26, 27], shorelines="1/0.5p" )
fig.basemap(frame="a")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=[127.5, 128.5, 26, 27], shorelines="1/0.5p" )
#fig.basemap(map_scale='jMB+c1+w10k+f+l')
fig.basemap(L='jMB+c1+w10k+f+l')
fig.show()

# %%
    fig_ref, fig_test = pygmt.Figure(), pygmt.Figure()
    fig_ref.coast(R="127.5/128.5/26/27", W="1/0.5p")
    fig_ref.basemap(L="jMB+c1+w10k+f")
    fig_test.coast(region=[127.5, 128.5, 26, 27], shorelines="1/0.5p")
    fig_test.basemap(map_scale="jMB+c1+w10k+f+l")

# %%
fig_ref.show()

# %%
fig_test.show()
