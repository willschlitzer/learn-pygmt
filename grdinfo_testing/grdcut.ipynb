# %%
import pygmt
from pygmt.helpers.testing import load_static_earth_relief
grid = load_static_earth_relief()

# %%
result = pygmt.grdcut(grid, region=[-53, -49, -20, -17])

# %%
result
# Out:
# <xarray.DataArray 'z' (lat: 3, lon: 4)>
# array([[446.5, 481.5, 439.5, 553. ],
#        [757. , 570.5, 538.5, 524. ],
#        [796. , 886. , 571.5, 638.5]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -52.5 -51.5 -50.5 -49.5
#   * lat      (lat) float64 -19.5 -18.5 -17.5
# Attributes:
#     long_name:     z
#     actual_range:  [439.5 886. ]

# %%
result.lon
# Out:
# <xarray.DataArray 'lon' (lon: 4)>
# array([-52.5, -51.5, -50.5, -49.5])
# Coordinates:
#   * lon      (lon) float64 -52.5 -51.5 -50.5 -49.5
# Attributes:
#     long_name:      longitude
#     units:          degrees_east
#     standard_name:  longitude
#     axis:           X
#     actual_range:   [-53. -49.]

# %%
result.lat
# Out:
# <xarray.DataArray 'lat' (lat: 3)>
# array([-19.5, -18.5, -17.5])
# Coordinates:
#   * lat      (lat) float64 -19.5 -18.5 -17.5
# Attributes:
#     long_name:      latitude
#     units:          degrees_north
#     standard_name:  latitude
#     axis:           Y
#     actual_range:   [-20. -17.]
