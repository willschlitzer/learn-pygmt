# %%
import pygmt
#grid = "@earth_relief_20m_holes.grd"
grid = pygmt.datasets.load_sample_data("earth_relief_holes")
import numpy as np
import numpy.testing as npt
import math

# %%
#print(grid[2, 19])
print(grid)
# Out:
# <xarray.DataArray 'z' (lat: 31, lon: 31)>
# array([[-4.7465e+03, -4.8995e+03, -4.8780e+03, -4.8280e+03, -4.7670e+03,
#         -4.2020e+03, -4.6125e+03, -4.2315e+03, -4.4280e+03, -4.3395e+03,
#         -4.2695e+03, -4.2030e+03, -4.1315e+03, -4.0535e+03, -3.9445e+03,
#         -3.8120e+03, -3.6175e+03, -3.3495e+03, -3.0330e+03, -2.3895e+03,
#         -1.3630e+03, -2.9280e+03, -2.8605e+03, -2.6725e+03, -2.3855e+03,
#         -1.8130e+03, -7.6550e+02, -7.5500e+01,  1.7500e+01,  4.1500e+01,
#          4.5000e+01],
#        [-4.9250e+03, -4.9170e+03, -4.8665e+03, -4.8350e+03, -4.7235e+03,
#         -4.6930e+03, -4.6240e+03, -4.4855e+03, -4.4570e+03, -4.3510e+03,
#         -4.3045e+03, -4.1880e+03, -4.1070e+03, -4.0345e+03, -3.9685e+03,
#         -3.8490e+03, -3.6620e+03, -3.4720e+03, -3.0075e+03, -2.2975e+03,
#          1.5450e+02, -2.7775e+03, -2.8660e+03, -2.7680e+03, -2.4625e+03,
#         -1.9645e+03, -9.4000e+02, -6.8500e+01, -3.5000e+00,  2.7500e+01,
#          7.4500e+01],
# ...

# %%
print(np.nan(grid[2, 19]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6834/1275804836.py in <module>
# ----> 1 print(np.nan(grid[2, 19]))
#
# TypeError: 'float' object is not callable

# %%
print(grid[2, 21].isnull())
# Out:
# <xarray.DataArray 'z' ()>
# array(True)
# Coordinates:
#     lon      float64 7.0
#     lat      float64 0.6667

# %%
assert math.isnan(grid[2, 16])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_10132/121945263.py in <module>
# ----> 1 assert math.isnan(grid[2, 16])
#
# AssertionError:

# %%
#fig = pygmt.Figure()
#fig.grdimage(grid=result)
#fig.show()

# %%
print(grid.min())
# Out:
# <xarray.DataArray 'z' ()>
# array(-4929.5, dtype=float32)
