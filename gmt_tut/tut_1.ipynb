# %%
import pygmt

# %%
fig = pygmt.Figure()

# %%
fig.basemap(region=[10, 70, -3, 8], projection="X4i/3i", frame=["af","""+glightred+t\"My First Plot\""""])

# %%
fig.show()

# %%
# Does not appear to be a way to have a title with a string that includes spaces
# Single quotes in the double-quoted string allows the title to be in, but the quotes are plotted as well
