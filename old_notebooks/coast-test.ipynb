# %%
import pygmt
#grid = pygmt.datasets.load_earth_relief(resolution="05m", region=[-86, -64 , 17, 24])

# %%
fig = pygmt.Figure()
#fig.grdimage(grid=grid)
fig.coast(
    region="US", #R
    borders=2,
    land="green",
    water="blue"
)
fig.show()
# Out:
# {'R': 'US', 'N': 2, 'G': 'green', 'S': 'blue'}
