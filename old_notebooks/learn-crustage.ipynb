# %%
import pygmt
grid = pygmt.datasets.load_seafloor_crust_age(resolution="03m", region=[-45, -35, 30, 40])
# Out:
# grdblend [NOTICE]: Remote data courtesy of GMT data server oceania [http://oceania.generic-mapping-tools.org]
# grdblend [NOTICE]: Earth Seafloor Crustal Age (GTS12 timescale) at 3x3 arc minutes from Gaussian Cartesian filtering (5.6 km fullwidth) of the 1m grid [Seton et al., 2020].
# grdblend [NOTICE]:   -> Download 90x90 degree grid tile (earth_age_03m_p): N00W090

# %%
fig = pygmt.Figure()
fig.grdimage(grid=grid)
fig.show()

# %%
print(pygmt.grdinfo(grid=grid))
# Out:
# : Title:
# : Command:
# : Remark:
# : Pixel node registration used [Geographic grid]
# : Grid file format: nf = GMT netCDF format (32-bit float), CF-1.7
# : x_min: -45 x_max: -35 x_inc: 0.05 (3 min) name: x n_columns: 200
# : y_min: 30 y_max: 40 y_inc: 0.05 (3 min) name: y n_rows: 200
# : v_min: 0.0100021362305 v_max: 104.660003662 name: z
# : scale_factor: 1 add_offset: 0
# : format: classic

# %%
fig = pygmt.Figure()
fig.grdimage(grid="@earth_age_03m", region=[-45, -35, 30, 40])
fig.show()

# %%
print(pygmt.grdinfo(grid="@earth_age_03m", region=[-45, -35, 30, 40], G=True))
# Out:
# GMTAPI@-S-O-G-G-G-Y-000002: Title:
# GMTAPI@-S-O-G-G-G-Y-000002: Command: grdblend @earth_age_03m_p/ -R-45/-35/30/40 -I03m -rp -G@GMTAPI@-S-O-G-G-G-Y-000002 -fg -Co+n
# GMTAPI@-S-O-G-G-G-Y-000002: Remark:
# GMTAPI@-S-O-G-G-G-Y-000002: Pixel node registration used [Geographic grid]
# GMTAPI@-S-O-G-G-G-Y-000002: Grid file format: nf = GMT netCDF format (32-bit float), CF-1.7
# GMTAPI@-S-O-G-G-G-Y-000002: x_min: -45 x_max: -35 x_inc: 0.05 (3 min) name: longitude n_columns: 200
# GMTAPI@-S-O-G-G-G-Y-000002: y_min: 30 y_max: 40 y_inc: 0.05 (3 min) name: latitude n_rows: 200
# GMTAPI@-S-O-G-G-G-Y-000002: v_min: 0.0100021362305 v_max: 104.660003662 name: z
# GMTAPI@-S-O-G-G-G-Y-000002: scale_factor: 1 add_offset: 0
# GMTAPI@-S-O-G-G-G-Y-000002: format: classic
