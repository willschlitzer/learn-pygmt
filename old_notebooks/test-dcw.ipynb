# %%
import pygmt

# %%
fig = pygmt.Figure()
#fig.basemap(region=[-92.5, -88, -2, 2.5], frame="a")
fig.coast(region=[-92.5, -88, -2, 0], land="gray", water="lightblue", projection="M10c")
fig.coast(region=[-92, -88, 0, 2.5], land="red", water="lightblue", projection="M10c")
fig.basemap(frame="a")
fig.show()
