# %%
import pygmt
region = [-74, -69.5, 41, 43]
inset_region = [-80, -65, 35, 50]
cmap="haxby"
grid = pygmt.datasets.load_earth_relief(resolution="05m", region=region)

# %%
fig = pygmt.Figure()
fig.coast(region=[-74, -69.5, 41, 43], borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue", frame="a")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=[-74, -69.5, 41, 43], borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue", frame="a")
with fig.inset(location="jBL+w3c", border="+pblack+glightred"):
    pass
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=[-74, -69.5, 41, 43], borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue", frame="a")
with fig.inset(location="jBC+w3c", border="+pblack+glightred"):
    pass
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=region, borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue", frame="a")
with fig.inset(location="jBL+w3c+o.5/0.2c", border="+gred"):
    pass
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=region, borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue", frame="a")
with fig.inset(location="jBL+w3c+o0.2/0.5c"):
    fig.coast(
    region=inset_region, projection="M3c", land="gray", borders=[1,2], shorelines="1/thin", water="white",  E="US.MA+gred"
        )
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=region, borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue", frame="a")

with fig.inset(location="jBL+w3c+o0.2/0.5c", margin=1.5, border="+pblack+gred"):
    pass
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=region, borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue")
fig.basemap(frame="a")
with fig.inset(location="jBL+w3c+o0.2c", margin=0, border="+pblack"):
    fig.coast(
    region=[-80, -65, 35, 50], projection="M3c", land="gray", borders=[1,2], shorelines="1/thin", water="white",  dcw="US.MA+gred"
        )
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region=region, borders="2/thin", shorelines="thin", projection="M15c", land="lightyellow", water="lightblue")

with fig.inset(location="jBL+w3c+o0.2c", margin=0, border="+pblack"):
    fig.coast(
    region=[-80, -65, 35, 50], projection="M3c", land="gray", borders=[1,2], shorelines="1/thin", water="white",  dcw="US.MA+gred"
        )
fig.basemap(frame="a")
fig.show()
