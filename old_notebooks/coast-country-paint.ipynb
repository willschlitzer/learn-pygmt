# %%
import pygmt

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", land="brown", water="azure", E=["ES+gbisque", "IT+gblue"])
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", land="brown", water="azure", E="ES+gbisque")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", land="brown", water="azure", paint_country="ES+gbisque")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", land="brown", paint_country="ES+gbisque+pblue")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", land="brown", water="azure", paint_country="ES,IT+gbisque+pgreen")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", G="brown", paint_country=["ES+gbisque+pgreen", "IT+gcyan+pblue"])
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-10, 15, 25, 44], frame="a", projection="M15c", land="brown", paint_country="=AF+gbisque+pblue")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(region = [-75, -69, 40, 44], frame="a", projection="M15c", land="brown", paint_country="US.MA+gbisque+pblue")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(
        region="-30/30/-40/40", #R
        projection="m0.1i", #J
        frame="afg", #B
        rivers="1/1p,black", #I
        borders="1/0.5p,-", #N
        shorelines="0.25p,white", #W
        land="moccasin", #G
        water="skyblue", #S
        resolution="i", #D
        area_thresh=1000, #A
    )
fig.show()
