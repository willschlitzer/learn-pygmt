# %%
import pygmt
import time

# %%
start = time.time()
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="d", projection="Cyl_stere/12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
print(time.time()-start)
# Out:
# 0.3205890655517578

# %%
start = time.time()
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="d", projection="Cyl_stere/12c", land="darkgray", water="white", frame="ag")
fig.show()

# %%
print(time.time()-start)
# Out:
# 0.2771015167236328

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="g", projection="Cyl_stere/12c", land="tomato1", water="skyblue", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="10/20/35/45", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="10/35/20/45+r", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region=[10,20,35,45], projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="JP", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="JP+r3", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="JP+r3/5", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="JP+r3/5/7/9", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="JP+R3", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
# Use region "d" to specify global region (-180/180/-90/90)
fig.coast(region="JP+e3", projection="M12c", land="lightgray", water="white", borders="1/0.5p", shorelines="1/0.5p", frame="ag")
fig.show()
