# %%
import pygmt
fig = pygmt.Figure()
region = [-74, -69, 41, 43]

fig.coast(region="US.MA", shorelines="1/thin", frame="a", rivers=[1,2, "a"], borders=2, projection="M25c")
fig.show()

# %%
import pygmt
fig = pygmt.Figure()
region = [-74, -69, 41, 43]

fig.coast(region="US.MA", shorelines=["1/thin", "2/thick"], frame="a", rivers=[1,2, "a"], borders=2, projection="M25c")
fig.show()

# %%
import pygmt
fig = pygmt.Figure()
region = [-74, -69, 41, 43]

fig.coast(region="US.MA", shorelines="1/1", frame="a", rivers=[1,2, "a"], borders=2, projection="M25c")
fig.show()
