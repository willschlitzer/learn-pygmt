# %%
import pygmt
region = [-92, -90, -1, 1]

# %%
print(pygmt.grdinfo(grid="gal_entire.nc"))
# Out:
# gal_entire.nc: Title: Bathymetry Grid
# gal_entire.nc: Command:
#  Projection: Cylindrical Equidistant
#  this grid created by the program MapApp 1.0b
# gal_entire.nc: Remark:
# gal_entire.nc: Gridline node registration used [Geographic grid]
# gal_entire.nc: Grid file format: cf = GMT netCDF format (32-bit float, deprecated)
# gal_entire.nc: x_min: -93.884765625 x_max: -86.0053710938 x_inc: 0.00439453125 name: Longitude n_columns: 1794
# gal_entire.nc: y_min: -1.99471412064 y_max: 2.52164648369 y_inc: 0.00439334689137 name: Latitude n_rows: 1029
# gal_entire.nc: v_min: -4111.44482422 v_max: -24.2304496765 name: Eleveation (m)
# gal_entire.nc: scale_factor: 1 add_offset: 0
# gal_entire.nc: format: classic

# %%
fig = pygmt.Figure()
pygmt.makecpt(cmap="turbo", series="-5000/0")
fig.grdimage(grid="gal_entire.nc", region=region, cmap=True,  projection="M20c", frame="a")
fig.show()
