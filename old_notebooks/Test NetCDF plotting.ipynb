# %%
import pygmt

# %%
fig = pygmt.Figure()
fig.grdcontour(grid="test.nc",region=[-92,-90, -1.5, .5])
fig.show()

# %%
fig = pygmt.Figure()
fig.grdcontour(grid="@earth_relief_15s",region=[-92,-90, -1.5, .5])
fig.show()
