# %%
import pygmt
import numpy as np

# %%
fig = pygmt.Figure()
table = [1,1,1,1,1,1,2,2,2,3,4,5,6,7,8,8,8,8,8,8]
np_table = np.array(table)
fig.histogram(table=table, projection="X10c/25c", interval=1, frame="a", fill="green")
fig.show()
