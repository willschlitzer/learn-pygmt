# %%
import pygmt

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M10i")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M10i")
fig.basemap(frame="f")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M10i")
fig.basemap(frame="a")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M10i")
fig.basemap(frame=["afg", "nSW"])
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M10i")
fig.basemap(frame="ag")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M10i")
#fig.basemap(frame=["ag", "+tMap"])
fig.basemap(frame="ag")
fig.basemap(frame="+tMap")
fig.show()
