# %%
import pygmt

# %%
fig = pygmt.Figure()
fig.grdimage(grid="@earth_relief_30m")
fig.colorbar()

KWARGS = dict(
    grid="@earth_relief_10m",
    region="g",
    projection="R-130/5i",
    frame=0)

# %%
fig.show()
